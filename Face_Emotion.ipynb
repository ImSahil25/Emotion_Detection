# %%
import cv2

# %%
from deepface import DeepFace

# %%
img = cv2.imread('./surp2.jpg')

# %%
import matplotlib.pyplot as plt
plt.imshow(img)

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
predictions = DeepFace.analyze(img)
# Out:
# Action: race: 100%|██████████| 4/4 [00:00<00:00,  5.73it/s]

# %%
predictions
# Out:
# [{'emotion': {'angry': 4.74159058683199e-06,
#    'disgust': 6.293221017006009e-13,
#    'fear': 2.3165546357631683,
#    'happy': 5.364690469633615e-07,
#    'sad': 2.2765767937471537e-06,
#    'surprise': 97.68343567848206,
#    'neutral': 5.55721863925579e-11},
#   'dominant_emotion': 'surprise',
#   'region': {'x': 281,
#    'y': 93,
#    'w': 214,
#    'h': 214,
#    'left_eye': (430, 184),
#    'right_eye': (344, 184)},
#   'face_confidence': 0.93,
#   'age': 26,
#   'gender': {'Woman': 0.0019148117644363083, 'Man': 99.99808073043823},
#   'dominant_gender': 'Man',
#   'race': {'asian': 1.9768367597292406e-16,
#    'indian': 2.2181388109113312e-14,
#    'black': 100.0,
#    'white': 8.089044408730483e-22,
#    'middle eastern': 3.80852452492097e-21,
#    'latino hispanic': 3.35917550449417e-15},
#   'dominant_race': 'black'}]

# %%
print("Race:")
predictions[0]['dominant_race']
# Out:
# Race:
# 'black'

# %%
print("Emotion:")
predictions[0]['dominant_emotion']
# Out:
# Emotion:
# 'surprise'

# %%
print("Gender:")
predictions[0]['dominant_gender']
# Out:
# Gender:
# 'Man'

# %%
print("Age:")
predictions[0]['age']
# Out:
# Age:
# 26
